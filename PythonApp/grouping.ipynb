# %%
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify
from sqlalchemy import create_engine

from flask import Response,json

from flask import Flask, jsonify

#from flask_cors import CORS, cross_origin

from flask import Flask, render_template

#################################################
# Database Setup
#################################################
# engine = create_engine("postgres://ucicakrprsnpky:0c02ab311d9965df2f4c471d98f6251dd952fb1263e3962e33a9f4c4ae7fbc78@ec2-54-158-222-248.compute-1.amazonaws.com:5432/dfkdt10l1i8e55")

engine = create_engine("postgres://dijotinjkotssd:db7fb60a896f20e945fe8d81cfa2b4d07537011ed1ffec0d02b3d9407bd982a6@ec2-3-214-3-162.compute-1.amazonaws.com:5432/decuhc9k7edl3j")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table

results = engine.execute("select * from breweries").fetchall()

# %%
import pandas as pd
df = pd.DataFrame(results)

# %%
df.head()
# Out:
#                                    0                                1      2   \
# 0          10-56-brewing-company-knox            10-56 Brewing Company  micro
# 1  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub  large
# 2    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise  large
# 3  10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver  large
# 4       10-barrel-brewing-co-portland             10 Barrel Brewing Co  large
#
#                     3              4              5         6         7   \
# 0        400 Brown Cir  Not Available  Not Available      Knox   Indiana
# 1     62950 NE 18th St  Not Available  Not Available      Bend    Oregon
# 2     826 W Bannock St  Not Available  Not Available     Boise     Idaho
# 3       2620 Walnut St  Not Available  Not Available    Denver  Colorado
# 4  1411 NW Flanders St  Not Available  Not Available  Portland    Oregon
#
# ...

# %%
columns = engine.execute("SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'breweries'").fetchall()

# %%
new_columns = []
for i in columns:
    new_columns.append(i[0])

# %%
new_columns
# Out:
# ['obdb_id',
#  'name',
#  'brewery_type',
#  'street',
#  'address_2',
#  'address_3',
#  'city',
#  'state',
#  'county_province',
#  'postal_code',
#  'website_url',
#  'phone',
#  'created_at',
#  'updated_at',
#  'country',
#  'longitude',
#  'latitude',
#  'tags',
#  'region_delete',
#  'state2',
#  'state_code',
#  'region',
#  'division']

# %%
df.columns = new_columns

# %%
df
# Out:
#                                  obdb_id                             name  \
# 0             10-56-brewing-company-knox            10-56 Brewing Company
# 1     10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 2       10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 3     10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 4          10-barrel-brewing-co-portland             10 Barrel Brewing Co
# ...                                  ...                              ...
# 4931       zorn-brew-works-michigan-city                  Zorn Brew Works
# 4932  zuni-street-brewing-company-denver      Zuni Street Brewing Company
# 4933           zwanzigz-brewing-columbus                 ZwanzigZ Brewing
# 4934             zydeco-brew-werks-tampa                Zydeco Brew Werks
# 4935         zymurgy-brew-works-torrance               Zymurgy Brew Works
#
#      brewery_type                street      address_2      address_3  \
# ...

# %%
df = df.dropna(how='any')
df
# Out:
#                                  obdb_id                             name  \
# 0             10-56-brewing-company-knox            10-56 Brewing Company
# 1     10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 2       10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 3     10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 4          10-barrel-brewing-co-portland             10 Barrel Brewing Co
# ...                                  ...                              ...
# 4931       zorn-brew-works-michigan-city                  Zorn Brew Works
# 4932  zuni-street-brewing-company-denver      Zuni Street Brewing Company
# 4933           zwanzigz-brewing-columbus                 ZwanzigZ Brewing
# 4934             zydeco-brew-werks-tampa                Zydeco Brew Werks
# 4935         zymurgy-brew-works-torrance               Zymurgy Brew Works
#
#      brewery_type                street      address_2      address_3  \
# ...

# %% [markdown]
# # list the region into dictionary

# %%
index_list = df.region.unique().tolist()
print(index_list)
# Out:
# ['Midwest', 'West', 'Northeast', 'South']

# %%
def Convert(index_list):
    res_dct = {index_list[i]: index_list[i + 1] for i in range(0, len(index_list), 2)}
    return res_dct

# %%
print(Convert(index_list))
# Out:
# {'Midwest': 'West', 'Northeast': 'South'}

# %% [markdown]
# # list the total number of each brewery type for each region

# %%
df1 = df.groupby(['region', 'brewery_type']).agg({'brewery_type':'count'})
df1
# Out:
#                         brewery_type
# region    brewery_type
# Midwest   brewpub                561
#           closed                   8
#           contract                28
#           large                    9
#           micro                  637
#           nano                     1
#           proprietor               9
#           regional                39
# Northeast brewpub                277
#           contract                24
#           large                    4
#           micro                  422
#           proprietor              10
#           regional                36
# South     brewpub                301
#           closed                   2
#           contract                25
#           large                   15
#           micro                  707
#           planning                13
#           proprietor               8
#           regional                31
# West      bar                      1
#           brewpub                613
# ...

# %%
data_dict = df1.to_dict()
data_dict
# Out:
# {'brewery_type': {('Midwest', 'brewpub'): 561,
#   ('Midwest', 'closed'): 8,
#   ('Midwest', 'contract'): 28,
#   ('Midwest', 'large'): 9,
#   ('Midwest', 'micro'): 637,
#   ('Midwest', 'nano'): 1,
#   ('Midwest', 'proprietor'): 9,
#   ('Midwest', 'regional'): 39,
#   ('Northeast', 'brewpub'): 277,
#   ('Northeast', 'contract'): 24,
#   ('Northeast', 'large'): 4,
#   ('Northeast', 'micro'): 422,
#   ('Northeast', 'proprietor'): 10,
#   ('Northeast', 'regional'): 36,
#   ('South', 'brewpub'): 301,
#   ('South', 'closed'): 2,
#   ('South', 'contract'): 25,
#   ('South', 'large'): 15,
#   ('South', 'micro'): 707,
#   ('South', 'planning'): 13,
#   ('South', 'proprietor'): 8,
#   ('South', 'regional'): 31,
#   ('West', 'bar'): 1,
#   ('West', 'brewpub'): 613,
#   ('West', 'closed'): 21,
#   ('West', 'contract'): 41,
#   ('West', 'large'): 24,
#   ('West', 'micro'): 914,
#   ('West', 'planning'): 87,
#   ('West', 'proprietor'): 16,
#   ('West', 'regional'): 51}}

# %% [markdown]
# # list the total number of brewery in each state for each region

# %%
df2 = df.groupby(['region', 'state']).agg({'brewery_type':'count'})
df2
# Out:
#                                 brewery_type
# region    state
# Midwest   Illinois                       153
#           Indiana                         87
#           Iowa                            71
#           Kansas                          31
#           Michigan                       270
#           Minnesota                      124
#           Missouri                       130
#           Nebraska                        31
#           North Dakota                     9
#           Ohio                           217
#           South Dakota                    11
#           Wisconsin                      158
# Northeast Connecticut                     45
#           Maine                           66
#           Massachusetts                  100
#           New Hampshire                   42
#           New Jersey                      58
#           New York                       228
#           Pennsylvania                   192
# ...

# %%
df["region"].value_counts().to_dict()
